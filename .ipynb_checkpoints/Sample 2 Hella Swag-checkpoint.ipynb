# %% [markdown]
# #### Hella Swag
# #### Research paper:
# #### Copy of data:

# %%
#!pip install import-ipynb

# %%
import sys
sys.path.append('../Modules')
sys.path.append('../Modules/Processors from Prof')

from Packages import *
import contextlib


# Import Jupyter Notebook files
with contextlib.redirect_stdout(None):
    #ToDo import the correct data processor: JSON or CSV
    from ipynb.fs.full.Json_Processor import *
    from ipynb.fs.full.CSV_Processor import *
    from ipynb.fs.full.Reading_Level import *
    from ipynb.fs.full.Word_Processing import *
    from ipynb.fs.full.Utilities import *
    from Wordcloud import *

# %%
def get_random_question(questions):
    '''
    Extract a random question 
    @param list questions: a list of dictionaries, each a question. 
    @param str source_id: the desired source of the question. Defaults to None for don't care.  
    @return: The random question as a dictionary
    '''
    return random.choice(questions)

# %%
def print_question(question):
    '''
    Print a question
    @param question dictionary: The question to be printed
    @return: None
    '''
    #print("print_question():", question)
    print("Input:", question["input"])
    print("Target:", question["target"])

# %%
def get_json_files(path):
    '''
    Extract json files from a list of file paths
    @param path list: The list to be processed
    @return list: The list of files with the extension ".json"
    '''
    all_files = read_directory_contents(path)
    return [file for file in all_files if file.endswith("json")]

# %%
def load_questions(benchmark_name, question_path):
    '''
    Read questions from a directory containing one or more quesiton files
    @param question_path string: The location of the question file(s)
    @return dictionary: key "questions" is a list of dictionaries, one dictionary for each question. Key "json_files" is a list of the file names that were processed
    '''
    results = dict()
    # Example usage:
    #input_file_path = r'Questions\boolean_expressions.json'
    #input_file_path = r'Questions\causal_judgement.json'
    #input_file_path = r'Questions\penguins_in_a_table.json'
    output_file_path = 'output.json'
    json_files = get_json_files(benchmark_name + "/"  + question_path)
    #print(json_files)

    json_processor = Big_Bench_Json_Processor(benchmark_name + "/" + question_path, json_files, output_file_path)
    questions = json_processor.read_json()
    results["questions"] = questions
    results["json_files"] = json_files
    return results

# %%
def build_text_from_questions(questions, write_to = None):
    '''
    Build one long text string from all the questions.
    This logic will vary based on the architecture of the benchmark questions.
    @param questions list: list of dictionaries, one dictionary per question.
    @param write_to string: File path to write the text string. Default is None. 
    @return String: The text string
    '''
    text = ""
    for question in questions:
        text += " " + str(question["input"]) + " " + str(question["target"])
    if write_to != None:
        write_string_to_file(text, write_to)

    #print("************************************", "HIGHTECH", "HIGHTECH" in text, text.find("HIGHTECH"))        
    return text

# %%
def compute_readability_indices(benchmark_name, questions, verbose = True):
    '''
    Compute readability values using our Reading_Level class
    @param questions list: A list of dictionaries, one dictionary per benchmark question
    @param verbose bool: True if this function should print the computed values
    @return dictionary: key is the readability metric, value is the corresponding score
    '''
    text = build_text_from_questions(questions)
    indices = Reading_Level.compute_readability_indices(benchmark_name, text)

    if (verbose):
        print("Readability Indices:")
        for index, score in indices.items():
            print(f"{index}: {score:.2f}")
    return indices

# %%
def generate_wordcloud(benchmark_name, questions):
    '''
    Build a word cloud based on the questions in a benchmark
    @param questions list: List of dictionaries, each dictionary os a question from the benchmark
    @return None
    '''
    text = build_text_from_questions(questions)

    wordcloud = Wordcloud()
    wordcloud.generate01(benchmark_name, text, myStopwords={"Numerical", "options"})

# %%
def compute_word_frequency(benchmark_name, questions, verbose = True, min_percentage = 1.0):
    '''
    Compute the word frequencies in the benchmark questions
    @param questions list: List of dictionaries, each dictionary os a question from the benchmark
    @param verbose bool: True if the function should print the word frequencies
    @param min_percentage float: the smallest percentage that should be printed. Defaults to 1.0
    @return set (dictionary, float): ({word:# of times that word appears over all questions}, total words)
    '''
    text = build_text_from_questions(questions)

    word_frequency, count = Word_Processing.compute_word_frequency(text)
    sorted_word_frequency = {k: v for k, v in sorted(word_frequency.items(), key=lambda item: item[1], reverse = True)}
    count = float(count)
    write_dict_to_file(sorted_word_frequency, ".\\" + benchmark_name + "\\results\\word_frequency.txt", length = 100, denominator = count)
    if verbose:
        print("Word Frequency:")
        #for key in [key for key in sorted_word_frequency.keys()][:5]:
        for key in sorted_word_frequency.keys():
            percentage = (sorted_word_frequency[key] / count)* 100
            if percentage >= min_percentage:
                print(key, ":", sorted_word_frequency[key], ",", '{0:.2f}'.format(percentage))

    return (sorted_word_frequency, count)

# %%
def compute_longest_words(benchmark_name, questions, verbose = True):
    '''
    Compute the longest words appearing across all the questions
    @param questions list: List of dictionaries, each dictionary is a question from the benchmark
    @param verbose bool: True if the function should print the words
    @return set (dictionary, float): ({word:# of times that word appears over all questions}, total words)    
    '''

    text = build_text_from_questions(questions)

    word_length, count = Word_Processing.compute_longest_words(text, min_length = 12)
    #sorted_word_lengths = {k: v for k, v in sorted(word_length.items(), key=lambda item: item[1], reverse = True)}
    sorted_word_lengths = {k: v for k, v in sorted(word_length.items(), key=lambda item: len(item[0]), reverse = True)}
    count = float(count)
    if verbose:
        print("Longest Words:")
        for key in list(sorted_word_lengths.keys())[0:25]:
            print(len(key), ", ", key, ":", sorted_word_lengths[key], ",", '{0:.2f}'.format((sorted_word_lengths[key] / count)* 100))

    # Write all the missing words to a text file
    write_dict_keys_to_file(sorted_word_lengths, ".\\" + benchmark_name + "\\results\\longest_words.txt", 100)

    return (sorted_word_lengths, count)

# %%
def find_word(questions, word):
    return Word_Processing.find_word(questions, word)

# %%
def find_missing_words(benchmark_name, questions, verbose = True, very_verbose = False):
    """
    Find words not in the English dictionary. Numbers are ignired in this function.
    @param questions dictionary: The data to be processed
    @param verbose bool: If true, print some information about the first 10 words not found in the dictionary. Default to True
    @param very_verbose bool: If true, print the questions containing the first 10 words that were not found in the dictionary. Default to False.
    
    @return dictionary: The unique words. key and value are both the unique word
    """
    text = build_text_from_questions(questions, ".\\" + benchmark_name + "\\results\\questions_as_text.txt")
    print("Text built...")
    english = Word_Processing.load_dictionary()
    print("Dictionary loaded...")

    words = Word_Processing.split_text(text)
    print("Text split...")
    words_not_found = dict()
    print("Processing word list...")
    for word in words:
        try:
            # If this fails, the word is not a number and we will add it to the dictionary of missing words.
            tmp = float(word)
        except:
            if word.upper() not in english:
                words_not_found[word] = word
                #words_not_found.add(word)
    # Write all the missing words to a text file
    write_dict_keys_to_file(words_not_found, ".\\" + benchmark_name + "\\results\\words_not_in_dictionary.txt", length = len(words_not_found))

    if verbose:
        print(len(words_not_found), "words not in dictionary")
        print("First 10 words not in dictionary:")
        for i, key in enumerate(words_not_found.keys()):
            if i >= 10:
              break
            print(key)
    if very_verbose:
        print("First 10 words not in dictionary and the questions those words appear in:")
        for i, key in enumerate(words_not_found.keys()):
            if i >= 10:
                break
            print(key)
            print(key , "found in", find_word(questions, key))
    
    return words_not_found

# %%
def demo():
    benchmark_name = "HellaSwag"
    input_file_path = 'HellaSwag/data/hellaswag_train.json'
    output_file_path = 'HellaSwag/data/output.json'
    question_path = "HellaSwag/data/"
    
    json_processor = HellaSwag_Json_Processor(input_file_path, output_file_path)
    questions = json_processor.read_data()

    print(len(questions), "questions read from", input_file_path)
    print(len(questions), "questions read from", len(json_files), "files in", question_path)

    random_question = get_random_question(questions)

    words_not_found = find_missing_words(benchmark_name, questions)

    print("Random question:")
    print_question(random_question)
    
    compute_readability_indices(benchmark_name, questions)
    
    generate_wordcloud(benchmark_name, questions)

    compute_word_frequency(benchmark_name, questions)
    
    compute_longest_words(benchmark_name, questions)

# %%
demo()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 demo()
#
# Cell In[60], line 8, in demo()
#       5 question_path = "HellaSwag/data/"
#       7 json_processor = HellaSwag_Json_Processor(input_file_path, output_file_path)
# ----> 8 questions = json_processor.read_data()
#      10 print(len(questions), "questions read from", input_file_path)
#      11 print(len(questions), "questions read from", len(json_files), "files in", question_path)
#
# File ~/Library/CloudStorage/OneDrive-UniversityofCincinnati/Undergraduate Research/Modules/Processors from Prof/Json_Processor.ipynb:219, in read_data(self)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "id": "52797adf-a700-41ea-b718-5db09ae24dd2",
#       6    "metadata": {},
#       7    "source": [
#       8     "#### Json Processors for questions in some specific Benchmarks"
#       9    ]
#      10   },
#      11   {
#      12    "cell_type": "code",
#      13    "execution_count": 1,
#      14    "id": "e5be2ad5-7278-4bb2-8237-dd69d3872a2e",
#      15    "metadata": {},
#      16    "outputs": [],
#      17    "source": [
#      18     "# Bill Nicholson\n",
#      19     "# nicholdw@ucmail.uc.edu"
#      20    ]
#      21   },
#      22   {
#      23    "cell_type": "code",
#      24    "execution_count": 2,
#      25    "id": "8c57f736-d40e-4095-881c-4f49d1bc5809",
#      26    "metadata": {},
#      27    "outputs": [],
#      28    "source": [
#      29     "import json"
#      30    ]
#      31   },
#      32   {
#      33    "cell_type": "code",
#      34    "execution_count": 3,
#      35    "id": "8ef8347a-85c8-4880-9997-6bf2a5a103eb",
#      36    "metadata": {},
#      37    "outputs": [],
#      38    "source": [
#      39     "class ARC_Challenge_Json_Processor:\n",
#      40     "    '''\n",
#      41     "    Json Processor for questions in the ARC Challenge Benchmark\n",
#      42     "    '''\n",
#      43     "    def __init__(self, question_path, input_files):\n",
#      44     "        '''\n",
#      45     "        Constructor\n",
#      46     "        @param question_path string: the path to the files in the input_files list\n",
#      47     "        @param List input_files: a list of files to process\n",
#      48     "        '''\n",
#      49     "        self.question_path = question_path\n",
#      50     "        self.input_files = input_files\n",
#      51     "\n",
#      52     "    def read_data(self):\n",
#      53     "        '''\n",
#      54     "        read all the questions from all the json files into one big list of dictionaries\n",
#      55     "        The data in input_file is one dictionary per line\n",
#      56     "        @return List: Each entry in the list is a dictionary containing one question from the benchmark\n",
#      57     "        '''\n",
#      58     "        questions = []\n",
#      59     "        for input_file in self.input_files:\n",
#      60     "            #print(\"JsonProcessor.read_json(): reading\", self.question_path + input_file)\n",
#      61     "            with open('../' + self.question_path + input_file, 'r', encoding='utf-8') as file:\n",
#      62     "                for line in file:\n",
#      63     "                    #print(\"line:\", line)\n",
#      64     "                    line = json.loads(line)  # convert string to dictionary\n",
#      65     "                    #print(\"Json_Processor.read_json(): type(line):\", type(line))\n",
#      66     "                    question = dict()\n",
#      67     "                    tmp = line[\"question\"]\n",
#      68     "                    # tmp is a dictionary with keys \"stem\" and \"choices\"\n",
#      69     "                    #print(tmp.keys())\n",
#      70     "                    question[\"input\"] = tmp[\"stem\"]\n",
#      71     "                    targets = tmp[\"choices\"]\n",
#      72     "                    # targets is a list of dictionaries, We want the value from the key \"text\" in each dictionary\n",
#      73     "                    question[\"target\"] = \"\"\n",
#      74     "                    for target in targets:\n",
#      75     "                        question[\"target\"] += target[\"text\"] + \"\\n\"\n",
#      76     "\n",
#      77     "                    #rint('question[\"input\"]:', question[\"input\"])\n",
#      78     "                    #rint('question[\"target\"]:', question[\"target\"])\n",
#      79     "                    questions.append(question)\n",
#      80     "        return questions\n",
#      81     "\n",
#      82     "    def process_data(self, data):\n",
#      83     "        \"\"\"\n",
#      84     "        Doesn't do anything, yet.\n",
#      85     "        \"\"\"\n",
#      86     "        processed_data = data\n",
#      87     "        return processed_data\n",
#      88     "\n",
#      89     "    def write_json(self, processed_data):\n",
#      90     "        \"\"\"\n",
#      91     "        Doesn't do anything, yet.\n",
#      92     "        \"\"\"\n",
#      93     "        with open(self.output_file, 'w') as file:\n",
#      94     "            json.dump(processed_data, file, indent=2)\n",
#      95     "\n",
#      96     "    def process_json_files(self):\n",
#      97     "        \"\"\"\n",
#      98     "        Doesn't do anything, yet.\n",
#      99     "        \"\"\"\n",
#     100     "        data = self.read_json()\n",
#     101     "        processed_data = self.process_data(data)\n",
#     102     "        self.write_json(processed_data)"
#     103    ]
#     104   },
#     105   {
#     106    "cell_type": "code",
#     107    "execution_count": 4,
#     108    "id": "d7e031ae-8989-48de-91cc-2f334838675d",
#     109    "metadata": {},
#     110    "outputs": [],
#     111    "source": [
#     112     "class Big_Bench_Json_Processor:\n",
#     113     "    '''\n",
#     114     "    Json Processor for questions in the Big Bench Hard Benchmark\n",
#     115     "    '''\n",
#     116     "    def __init__(self, question_path, input_files):\n",
#     117     "        '''\n",
#     118     "        Constructor\n",
#     119     "        @param question_path string: the path to the files in the input_files list\n",
#     120     "        @param List input_files: a list of files to process\n",
#     121     "        '''\n",
#     122     "        self.question_path = question_path\n",
#     123     "        self.input_files = input_files\n",
#     124     "\n",
#     125     "    def read_data(self):\n",
#     126     "        '''\n",
#     127     "        read all the questions from all the json files into one big list of dictionaries\n",
#     128     "        The data in input_file is one dictionary per line\n",
#     129     "        @return List: Each entry in the list is a dictionary containing one question from the benchmark\n",
#     130     "        '''\n",
#     131     "        questions = []\n",
#     132     "        for input_file in self.input_files:\n",
#     133     "            #print(\"JsonProcessor.read_json(): reading\", self.question_path + input_file)\n",
#     134     "            with open('../' + self.question_path + input_file, 'r', encoding='utf-8') as file:\n",
#     135     "                for line in file:\n",
#     136     "                    #print(\"line:\", line)\n",
#     137     "                    line = json.loads(line)  # convert string to dictionary\n",
#     138     "                    #print(\"Json_Processor.read_json(): type(line):\", type(line))\n",
#     139     "                    text = line[\"examples\"]\n",
#     140     "                    for q in text:\n",
#     141     "                        question = dict()\n",
#     142     "                        question[\"input\"] = q[\"input\"]\n",
#     143     "                        # The possible answers are also in q[\"input\"], along with the question. \n",
#     144     "                        question[\"target\"] = q[\"target\"] # Just the correct answer\n",
#     145     "                        question[\"topic\"] = input_file   # Label the question so we know which topic (actually, file) it came from\n",
#     146     "                        questions.append(question)\n",
#     147     "        return questions\n",
#     148     "\n",
#     149     "    def process_data(self, data):\n",
#     150     "        \"\"\"\n",
#     151     "        Doesn't do anything, yet.\n",
#     152     "        \"\"\"\n",
#     153     "        processed_data = data\n",
#     154     "        return processed_data\n",
#     155     "\n",
#     156     "    def write_json(self, processed_data):\n",
#     157     "        \"\"\"\n",
#     158     "        Doesn't do anything, yet.\n",
#     159     "        \"\"\"\n",
#     160     "        with open(self.output_file, 'w') as file:\n",
#     161     "            json.dump(processed_data, file, indent=2)\n",
#     162     "\n",
#     163     "    def process_json_files(self):\n",
#     164     "        \"\"\"\n",
#     165     "        Doesn't do anything, yet.\n",
#     166     "        \"\"\"\n",
#     167     "        data = self.read_json()\n",
#     168     "        processed_data = self.process_data(data)\n",
#     169     "        self.write_json(processed_data)"
#     170    ]
#     171   },
#     172   {
#     173    "cell_type": "code",
#     174    "execution_count": 5,
#     175    "id": "d099d854-e209-4536-8975-c3954949ec20",
#     176    "metadata": {},
#     177    "outputs": [],
#     178    "source": [
#     179     "class Big_Bench_Json_Processor:\n",
#     180     "    '''\n",
#     181     "    Json Processor for questions in the Big Bench Hard Benchmark\n",
#     182     "    '''\n",
#     183     "    def __init__(self, question_path, input_files):\n",
#     184     "        '''\n",
#     185     "        Constructor\n",
#     186     "        @param question_path string: the path to the files in the input_files list\n",
#     187     "        @param List input_files: a list of files to process\n",
#     188     "        '''\n",
#     189     "        self.question_path = question_path\n",
#     190     "        self.input_files = input_files\n",
#     191     "\n",
#     192     "    def read_data(self):\n",
#     193     "        '''\n",
#     194     "        read all the questions from all the json files into one big list of dictionaries\n",
#     195     "        The data in input_file is one dictionary per line\n",
#     196     "        @return List: Each entry in the list is a dictionary containing one question from the benchmark\n",
#     197     "        '''\n",
#     198     "        questions = []\n",
#     199     "        for input_file in self.input_files:\n",
#     200     "            #print(\"JsonProcessor.read_json(): reading\", self.question_path + input_file)\n",
#     201     "            with open('../' + self.question_path + input_file, 'r', encoding='utf-8') as file:\n",
#     202     "                for line in file:\n",
#     203     "                    #print(\"line:\", line)\n",
#     204     "                    line = json.loads(line)  # convert string to dictionary\n",
#     205     "                    #print(\"Json_Processor.read_json(): type(line):\", type(line))\n",
#     206     "                    text = line[\"examples\"]\n",
#     207     "                    for q in text:\n",
#     208     "                        question = dict()\n",
#     209     "                        question[\"input\"] = q[\"input\"]\n",
#     210     "                        # The possible answers are also in q[\"input\"], along with the question. \n",
#     211     "                        question[\"target\"] = q[\"target\"] # Just the correct answer\n",
#     212     "                        question[\"topic\"] = input_file   # Label the question so we know which topic (actually, file) it came from\n",
#     213     "                        questions.append(question)\n",
#     214     "        return questions\n",
#     215     "\n",
#     216     "    def process_data(self, data):\n",
#     217     "        \"\"\"\n",
#     218     "        Doesn't do anything, yet.\n",
# --> 219     "        \"\"\"\n",
#     220     "        processed_data = data\n",
#     221     "        return processed_data\n",
#     222     "\n",
#     223     "    def write_json(self, processed_data):\n",
#     224     "        \"\"\"\n",
#     225     "        Doesn't do anything, yet.\n",
#     226     "        \"\"\"\n",
#     227     "        with open(self.output_file, 'w') as file:\n",
#     228     "            json.dump(processed_data, file, indent=2)\n",
#     229     "\n",
#     230     "    def process_json_files(self):\n",
#     231     "        \"\"\"\n",
#     232     "        Doesn't do anything, yet.\n",
#     233     "        \"\"\"\n",
#     234     "        data = self.read_json()\n",
#     235     "        processed_data = self.process_data(data)\n",
#     236     "        self.write_json(processed_data)"
#     237    ]
#     238   },
#     239   {
#     240    "cell_type": "code",
#     241    "execution_count": 6,
#     242    "id": "37f5c4fc-6a98-479e-afcd-e8c8a92fce3b",
#     243    "metadata": {},
#     244    "outputs": [],
#     245    "source": [
#     246     "class HellaSwag_Json_Processor:\n",
#     247     "    '''\n",
#     248     "    Json Processor for questions in the Hella Swag Benchmark\n",
#     249     "    '''\n",
#     250     "    def __init__(self, question_path, input_files):\n",
#     251     "        '''\n",
#     252     "        Constructor\n",
#     253     "        @param question_path string: the path to the files in the input_files list\n",
#     254     "        @param List input_files: a list of files to process\n",
#     255     "        '''\n",
#     256     "        self.question_path = question_path\n",
#     257     "        self.input_files = input_files\n",
#     258     "\n",
#     259     "    def read_data(self):\n",
#     260     "        '''\n",
#     261     "        read all the questions from all the json files into one big list of dictionaries\n",
#     262     "        The data in input_file is one dictionary per line\n",
#     263     "        @return: A list of dictionaries. Each dictionary is a question from the benchmark\n",
#     264     "        '''\n",
#     265     "        questions = []\n",
#     266     "        for input_file in self.input_files:\n",
#     267     "            #print(\"HellaSwag JsonProcessor.read_json(): reading\", self.question_path + input_file)\n",
#     268     "            with open(self.question_path + input_file, 'r', encoding='utf-8') as file:\n",
#     269     "                for line in file:\n",
#     270     "                    #print(\"line:\", line)\n",
#     271     "                    line = json.loads(line)  # convert string to dictionary\n",
#     272     "                    #print(\"Json_Processor.read_json(): type(line):\", type(line))\n",
#     273     "                    question = dict()\n",
#     274     "                    #*************************************\n",
#     275     "                    #ToDo map the questions/answers into our dictionary format\n",
#     276     "                    ending_prefix = line[\"ctx_b\"]\n",
#     277     "                    target = \"\"\n",
#     278     "                    question[\"input\"] = line[\"ctx_a\"]\n",
#     279     "                    question[\"topic\"] = line[\"activity_label\"]   # Label the question so we know which topic it came from\n",
#     280     "                    for ending in line[\"endings\"]:\n",
#     281     "                        target += ending_prefix + \" \" + ending + \"\\n\"\n",
#     282     "                    question[\"target\"] = target\n",
#     283     "                    #*************************************\n",
#     284     "                    questions.append(question)\n",
#     285     "        return questions\n",
#     286     "\n",
#     287     "    def process_data(self, data):\n",
#     288     "        \"\"\"\n",
#     289     "        Doesn't do anything, yet.\n",
#     290     "        \"\"\"\n",
#     291     "        processed_data = data\n",
#     292     "        return processed_data\n",
#     293     "\n",
#     294     "    def write_json(self, processed_data):\n",
#     295     "        \"\"\"\n",
#     296     "        Doesn't do anything, yet.\n",
#     297     "        \"\"\"\n",
#     298     "        with open(self.output_file, 'w') as file:\n",
#     299     "            json.dump(processed_data, file, indent=2)\n",
#     300     "\n",
#     301     "    def process_json_files(self):\n",
#     302     "        \"\"\"\n",
#     303     "        Doesn't do anything, yet.\n",
#     304     "        \"\"\"\n",
#     305     "        data = self.read_json()\n",
#     306     "        processed_data = self.process_data(data)\n",
#     307     "        self.write_json(processed_data)"
#     308    ]
#     309   }
#     310  ],
#     311  "metadata": {
#     312   "kernelspec": {
#     313    "display_name": "python_env",
#     314    "language": "python",
#     315    "name": "python3"
#     316   },
#     317   "language_info": {
#     318    "codemirror_mode": {
#     319     "name": "ipython",
#     320     "version": 3
#     321    },
#     322    "file_extension": ".py",
#     323    "mimetype": "text/x-python",
#     324    "name": "python",
#     325    "nbconvert_exporter": "python",
#     326    "pygments_lexer": "ipython3",
#     327    "version": "3.12.7"
#     328   }
#     329  },
#     330  "nbformat": 4,
#     331  "nbformat_minor": 5
#     332 }
#
# FileNotFoundError: [Errno 2] No such file or directory: 'HellaSwag/data/hellaswag_train.jsonH'

# %%
# if __name__ == "__main__":
#     demo()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
#       1 if __name__ == "__main__":
# ----> 2     demo()
#
# Input In [15], in demo()
#       5 question_path = "data/"
#       7 json_processor = Hella_Swag_Json_Processor(input_file_path, output_file_path)
# ----> 8 questions = json_processor.read_json()
#      10 print(len(questions), "questions read from", input_file_path)
#      11 print(len(questions), "questions read from", len(json_files), "files in", question_path)
#
# File <string>:15, in read_json(self)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/hellaswag_train.json'
